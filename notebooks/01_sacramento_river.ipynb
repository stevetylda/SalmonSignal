# %%
import pandas as pd

# %%
pd.read_excel('/Users/tylerstevenson/Documents/CODE/SalmonSignal/data/raw/red-bluff-diversion-dam-fish-counts/HISTORICAL COUNTS.xls')
# Out:
#     WEEKLY SUMMARY RBDD LADDER COUNTS                      Unnamed: 1  \
# 0                      Late Fall Run                              NaN
# 1                                 NaN                            1966
# 2                                Year                            1967
# 3                                 NaN  (1967-1969 RECONSTRUCTED RUNS)
# 4                              Week #                             NaN
# ..                                ...                             ...
# 295                              Year                            1967
# 296                               NaN                             NaN
# 297                               NaN                           15312
# 298                               NaN                             NaN
# 299                               NaN                             NaN
#
#     Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# ...

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
